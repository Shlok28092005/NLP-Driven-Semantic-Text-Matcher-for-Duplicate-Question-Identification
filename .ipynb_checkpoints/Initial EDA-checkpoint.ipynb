# %% [markdown]
# # File 1

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Duplicate Question.csv")
df.shape
# Out:
# (404290, 6)

# %%
df.sample(5)
# Out:
#             id    qid1    qid2  \
# 365411  365411  495517  495518
# 228277  228277  337305  337306
# 324420  324420  450521  450522
# 130061  130061  101311  208801
# 79995    79995   71782  109620
#
#                                                 question1  \
# 365411  What do economists think of demonetization of ...
# 228277  Which one is better: Yonex Voltric 7 or Li-Nin...
# 324420                   Do I have low latent inhibition?
# 130061  What are the Best torrent sites to download from?
# 79995   Will Hillary Clinton run for president again i...
#
#                                                 question2  is_duplicate
# 365411  How much of taxpayer’s money is going to be sp...             0
# 228277  Which is better for power play (badminton), Ar...             0
# 324420                     What is low latent inhibition?             0
# 130061                   What are torrent download sites?             1
# 79995   Will Hillary run again in 2020 for the preside...             1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  str
#  4   question2     404288 non-null  str
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), str(2)
# memory usage: 18.5 MB

# %%
df.describe()
# Out:
#                   id           qid1           qid2   is_duplicate
# count  404290.000000  404290.000000  404290.000000  404290.000000
# mean   202144.500000  217243.942418  220955.655337       0.369198
# std    116708.614503  157751.700002  159903.182629       0.482588
# min         0.000000       1.000000       2.000000       0.000000
# 25%    101072.250000   74437.500000   74727.000000       0.000000
# 50%    202144.500000  192182.000000  197052.000000       0.000000
# 75%    303216.750000  346573.500000  354692.500000       1.000000
# max    404289.000000  537932.000000  537933.000000       1.000000

# %%
# Missing values 
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
# Duplicate rows 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Distribution of Duplicate and Non-Duplicate Questions 
print(df['is_duplicate'].value_counts())
print((df['is_duplicate'].value_counts() / df['is_duplicate'].count()) * 100)
print(df['is_duplicate'].value_counts().plot(kind='bar'))
# Out:
# is_duplicate
# 0    255027
# 1    149263
# Name: count, dtype: int64
# is_duplicate
# 0    63.080215
# 1    36.919785
# Name: count, dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %%
# Repeated Questions
qid = pd.Series(df['qid1'].to_list() + df['qid2'].to_list())
print("Number of unique questions -->", np.unique(qid).shape[0])
x = qid.value_counts()>1 
print('Number of questions getting repeated',x[x].shape[0])
# Out:
# Number of unique questions --> 537933
# Number of questions getting repeated 111780

# %%
# Plotting Histogram 
plt.hist(qid.value_counts().values,bins=200)
plt.yscale('log')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
